# %% [markdown]
# # Data Cleaning and Preprocessing
#
# The objective of this notebook is to evaluate data quality and prepare the dataset for analysis and machine learning.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../Data/raw/customer_churn_data.csv")

# %%
df.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %% [markdown]
# ### Missing Values Analysis
#
# No missing values were identified in the dataset. This indicates that the dataset is complete and does not require imputation techniques.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Duplicate Records
#
# Duplicate records were checked to ensure that each row represents a unique customer.
#
# No duplicate records were identified.

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# ### Summary Statistics
#
# The descriptive statistics provide an overview of the numerical variables including mean, minimum, maximum, and standard deviation values.
#
# These statistics help identify potential outliers and understand customer usage patterns.

# %%
df.drop("phone number", axis=1, inplace=True)

df.to_csv("../data/processed/telecom_churn_cleaned.csv",
          index=False)

# %% [markdown]
# ### Feature Removal
#
# The phone number variable was removed because it serves only as a customer identifier and does not contribute meaningful information for predicting churn.
