# %% [markdown]
# # Data Collection
#
# ## Introduction
#
# The purpose of this notebook is to load the telecommunications customer churn dataset, inspect its structure, and store the raw data for future processing.
#
# ## Objectives
#
# - Load the dataset.
# - Inspect the dataset dimensions.
# - Review column names and data types.
# - Create a data dictionary.
# - Store the dataset in the raw data folder.
